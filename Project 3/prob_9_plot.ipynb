# %%
# multidimensional arrays
import numpy as np
import math

# inline plots
import matplotlib.pyplot as plt
# %matplotlib inline

# nicer figures
import matplotlib as mpl
mpl.rcParams['axes.titlesize'] = 16
mpl.rcParams['axes.labelsize'] = 14
mpl.rcParams['xtick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12
mpl.rcParams['legend.fontsize'] = 7.5
plt.rcParams["figure.figsize"] = (7,5)

# %%
#reading time t
t = np.loadtxt("t_values.txt", usecols=0, dtype='double')

#reading r values
r_z = np.loadtxt("r_values.txt", usecols=2, dtype='double')

#reading v values
#v_x = np.loadtxt("v_values.txt", usecols=0, dtype='double')

# %%
# Plotting motion in the z direction as a function of time
plt.plot(t, r_z)

# add axis labels
plt.xlabel("Time [$\mu s$]")
plt.ylabel("Motion in z direction")

# add grid
plt.grid(linestyle = '--', linewidth = 0.2)

# save plot as pdf
plt.savefig("plot_9a.pdf")

# %%
#confront between omega values
T = 100/22 # period

omega_teo = 2*math.sqrt(2*9.65/40.08) # square root of 2qVo/md^2
omega_exp = 2*math.pi/T 

print("theoretical value",omega_teo)
print("experimental value",omega_exp)
# Out:
# theoretical value 1.38785723494559
# experimental value 1.382300767579509

# %%
#reading time t
t = np.loadtxt("time.txt", usecols=0, dtype='double')

# %%
#with interaction
#reading r values two particles
r_x_1 = np.loadtxt("xy1_inter.txt", usecols=0, dtype='double')
r_y_1 = np.loadtxt("xy1_inter.txt", usecols=1, dtype='double')

r_x_2 = np.loadtxt("xy2_inter.txt", usecols=0, dtype='double')
r_y_2 = np.loadtxt("xy2_inter.txt", usecols=1, dtype='double')

# %%
# Plotting motion of two particles with interactions
plt.plot(r_x_1, r_y_1, color="blue",label="particle 1")
plt.plot(r_x_2, r_y_2, color="red",label="particle 2")

# add axis labels and legend
plt.xlabel("x")
plt.ylabel("y")
plt.legend()

# add grid
plt.grid(linestyle = '--', linewidth = 0.2)

# save plot as pdf
plt.savefig("plot_9b.pdf")

# %%
#no interaction
#reading r values two particles
r_x_1 = np.loadtxt("xy1_nointer.txt", usecols=0, dtype='double')
r_y_1 = np.loadtxt("xy1_nointer.txt", usecols=1, dtype='double')

r_x_2 = np.loadtxt("xy2_nointer.txt", usecols=0, dtype='double')
r_y_2 = np.loadtxt("xy2_nointer.txt", usecols=1, dtype='double')

# %%
# Plotting motion of two particles with no interactions
plt.plot(r_x_1, r_y_1, color="blue",label="particle 1")
plt.plot(r_x_2, r_y_2, color="red",label="particle 2")

# add axis labels and legend
plt.xlabel("x")
plt.ylabel("y")
plt.legend()

# add grid
plt.grid(linestyle = '--', linewidth = 0.2)

# save plot as pdf
plt.savefig("plot_9b.pdf")

# %%
# 3D plot

ax = plt.axes(projection='3d')
