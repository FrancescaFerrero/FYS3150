# %%
# multidimensional arrays
import numpy as np
import math

# inline plots
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.colors import LogNorm
import matplotlib.colors as colors
import matplotlib.cbook as cbook
from matplotlib import cm


# nicer figures
import matplotlib as mpl
mpl.rcParams['axes.titlesize'] = 16
mpl.rcParams['axes.labelsize'] = 14
mpl.rcParams['xtick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12
mpl.rcParams['legend.fontsize'] = 12
plt.rcParams["figure.figsize"] = (7,5)

# 3d plot
from mpl_toolkits import mplot3d

# vector norm
from numpy import linalg as LA

# %%
# reading time t
t_1e2 = np.loadtxt("t_100.txt", dtype='double') 
t_1e3 = np.loadtxt("t_1000.txt", dtype='double')             
t_1e4 = np.loadtxt("t_10000.txt", dtype='double')
t_1e5 = np.loadtxt("t_100000.txt", dtype='double')
t_1e6 = np.loadtxt("t_1000000.txt", dtype='double')
#t_1e7 = np.loadtxt("t_10000000.txt", dtype='double')  

# reading experimental r values - Runge-Kutta
r_1e2_RK_exp = np.loadtxt("r1_nointer_RK_100.txt", dtype='double')
r_1e3_RK_exp = np.loadtxt("r1_nointer_RK_1000.txt", dtype='double')
r_1e4_RK_exp = np.loadtxt("r1_nointer_RK_10000.txt", dtype='double')
r_1e5_RK_exp = np.loadtxt("r1_nointer_RK_100000.txt", dtype='double')
r_1e6_RK_exp = np.loadtxt("r1_nointer_RK_1000000.txt", dtype='double')
#r_1e7_RK_exp = np.loadtxt("r1_nointer_RK_10000000.txt", dtype='double')

# reading experimental r values - Forward Euler
r_1e2_FE_exp = np.loadtxt("r1_nointer_FE_100.txt", dtype='double')
r_1e3_FE_exp = np.loadtxt("r1_nointer_FE_1000.txt", dtype='double')
r_1e4_FE_exp = np.loadtxt("r1_nointer_FE_10000.txt", dtype='double')
r_1e5_FE_exp = np.loadtxt("r1_nointer_FE_100000.txt", dtype='double')
r_1e6_FE_exp = np.loadtxt("r1_nointer_FE_1000000.txt", dtype='double')
#r_1e7_FE_exp = np.loadtxt("r1_nointer_FE_10000000.txt", dtype='double')

# reading analytical r values
r_1e2_an = np.loadtxt("r_analytic.100.txt", dtype='double')
r_1e3_an = np.loadtxt("r_analytic.1000.txt", dtype='double')
r_1e4_an = np.loadtxt("r_analytic.10000.txt", dtype='double')
r_1e5_an = np.loadtxt("r_analytic.100000.txt", dtype='double')
r_1e6_an = np.loadtxt("r_analytic.1000000.txt", dtype='double')
#r_1e7_an = np.loadtxt("r_analytic.10000000.txt", dtype='double')

# %%
# Calculating relative errors FE

rel_err_FE_1e2 = np.zeros(np.size(t_1e2))
rel_err_FE_1e3 = np.zeros(np.size(t_1e3))
rel_err_FE_1e4 = np.zeros(np.size(t_1e4))
rel_err_FE_1e5 = np.zeros(np.size(t_1e5))
rel_err_FE_1e6 = np.zeros(np.size(t_1e6))
#rel_err_FE_1e7 = np.zeros(np.size(t_1e7))

for i in range(np.size(t_1e2)):
    rel_err_FE_1e2[i] = LA.norm(r_1e2_an[i]-r_1e2_FE_exp[i])/LA.norm(r_1e2_an[i])

for i in range(np.size(t_1e3)):
    rel_err_FE_1e3[i] = LA.norm(r_1e3_an[i]-r_1e3_FE_exp[i])/LA.norm(r_1e3_an[i]) 

for i in range(np.size(t_1e4)):
    rel_err_FE_1e4[i] = LA.norm(r_1e4_an[i]-r_1e4_FE_exp[i])/LA.norm(r_1e4_an[i]) 

for i in range(np.size(t_1e5)):
    rel_err_FE_1e5[i] = LA.norm(r_1e5_an[i]-r_1e5_FE_exp[i])/LA.norm(r_1e5_an[i]) 

for i in range(np.size(t_1e6)):
    rel_err_FE_1e6[i] = LA.norm(r_1e6_an[i]-r_1e6_FE_exp[i])/LA.norm(r_1e6_an[i])
    
#for i in range(np.size(t_1e7)):
#    rel_err_FE_1e7[i] = LA.norm(r_1e7_an[i]-r_1e7_FE_exp[i])/LA.norm(r_1e7_an[i])     

# Calculating relative errors RK

rel_err_RK_1e2 = np.zeros(np.size(t_1e2))
rel_err_RK_1e3 = np.zeros(np.size(t_1e3))
rel_err_RK_1e4 = np.zeros(np.size(t_1e4))
rel_err_RK_1e5 = np.zeros(np.size(t_1e5))
rel_err_RK_1e6 = np.zeros(np.size(t_1e6))
#rel_err_RK_1e7 = np.zeros(np.size(t_1e7))

for i in range(np.size(t_1e2)):
    rel_err_RK_1e2[i] = LA.norm(r_1e2_an[i]-r_1e2_RK_exp[i])/LA.norm(r_1e2_an[i])

for i in range(np.size(t_1e3)):
    rel_err_RK_1e3[i] = LA.norm(r_1e3_an[i]-r_1e3_RK_exp[i])/LA.norm(r_1e3_an[i]) 

for i in range(np.size(t_1e4)):
    rel_err_RK_1e4[i] = LA.norm(r_1e4_an[i]-r_1e4_RK_exp[i])/LA.norm(r_1e4_an[i]) 

for i in range(np.size(t_1e5)):
    rel_err_RK_1e5[i] = LA.norm(r_1e5_an[i]-r_1e5_RK_exp[i])/LA.norm(r_1e5_an[i]) 

for i in range(np.size(t_1e6)):
    rel_err_RK_1e6[i] = LA.norm(r_1e6_an[i]-r_1e6_RK_exp[i])/LA.norm(r_1e6_an[i])
    
#for i in range(np.size(t_1e7)):
#    rel_err_RK_1e7[i] = LA.norm(r_1e7_an[i]-r_1e7_RK_exp[i])/LA.norm(r_1e7_an[i])

# %%
# Calculating absolute errors FE

abs_err_FE_1e2 = np.zeros(np.size(t_1e2))
abs_err_FE_1e3 = np.zeros(np.size(t_1e3))
abs_err_FE_1e4 = np.zeros(np.size(t_1e4))
abs_err_FE_1e5 = np.zeros(np.size(t_1e5))
abs_err_FE_1e6 = np.zeros(np.size(t_1e6))
#rel_err_FE_1e7 = np.zeros(np.size(t_1e7))

for i in range(np.size(t_1e2)):
    abs_err_FE_1e2[i] = LA.norm(r_1e2_an[i]-r_1e2_FE_exp[i])

for i in range(np.size(t_1e3)):
    abs_err_FE_1e3[i] = LA.norm(r_1e3_an[i]-r_1e3_FE_exp[i])

for i in range(np.size(t_1e4)):
    abs_err_FE_1e4[i] = LA.norm(r_1e4_an[i]-r_1e4_FE_exp[i])

for i in range(np.size(t_1e5)):
    abs_err_FE_1e5[i] = LA.norm(r_1e5_an[i]-r_1e5_FE_exp[i])

for i in range(np.size(t_1e6)):
    abs_err_FE_1e6[i] = LA.norm(r_1e6_an[i]-r_1e6_FE_exp[i])
    
#for i in range(np.size(t_1e7)):
#    rel_err_FE_1e7[i] = LA.norm(r_1e7_an[i]-r_1e7_FE_exp[i])/LA.norm(r_1e7_an[i])     

# Calculating absolute errors RK

abs_err_RK_1e2 = np.zeros(np.size(t_1e2))
abs_err_RK_1e3 = np.zeros(np.size(t_1e3))
abs_err_RK_1e4 = np.zeros(np.size(t_1e4))
abs_err_RK_1e5 = np.zeros(np.size(t_1e5))
abs_err_RK_1e6 = np.zeros(np.size(t_1e6))
#rel_err_RK_1e7 = np.zeros(np.size(t_1e7))

for i in range(np.size(t_1e2)):
    abs_err_RK_1e2[i] = LA.norm(r_1e2_an[i]-r_1e2_RK_exp[i])

for i in range(np.size(t_1e3)):
    abs_err_RK_1e3[i] = LA.norm(r_1e3_an[i]-r_1e3_RK_exp[i])

for i in range(np.size(t_1e4)):
    abs_err_RK_1e4[i] = LA.norm(r_1e4_an[i]-r_1e4_RK_exp[i])
    
for i in range(np.size(t_1e5)):
    abs_err_RK_1e5[i] = LA.norm(r_1e5_an[i]-r_1e5_RK_exp[i])

for i in range(np.size(t_1e6)):
    abs_err_RK_1e6[i] = LA.norm(r_1e6_an[i]-r_1e6_RK_exp[i])
    
#for i in range(np.size(t_1e7)):
#    rel_err_RK_1e7[i] = LA.norm(r_1e7_an[i]-r_1e7_RK_exp[i])/LA.norm(r_1e7_an[i])

# %%
print(abs_err_RK_1e2) 
print(np.max(abs_err_RK_1e2))
# Out:
# [ 0.0771      7.18803774 20.12812264 30.94445396 17.14517887  9.45904942
#   4.05963504  3.3598071  16.81708183 20.83722425 16.36239514  8.30796917
#  11.81230482  9.66790619  4.88613798  7.54621509 14.63290214  4.08781412
#  18.20674287 15.36834146 13.87723     3.95189553  8.55940113  8.13475633
#  17.90151994 24.43789573 24.87640597  5.23561418  4.10568177  7.91176416
#  13.62264951 30.32828207 25.56852416  8.7278567   4.35050097  4.0228991
#  10.51250198 26.09140517 18.85665893 12.50686148  3.69928964 11.86011542
#   4.27380974 12.44807834 13.09656403 10.35082203 11.83291454 17.96016732
#   8.99848483  4.12675379  9.63089722  4.68638877 16.97406529 20.26003631
#  23.61541994 13.03383168  4.02983873  5.28697528 13.92112065 23.09595742
#  31.14464682 13.99748687  4.89541938  4.02671175  4.94086169 23.5989272
#  27.23431625 12.87297159  6.04182459  7.83853926  4.44187426 15.72612398
#  15.50356992 13.32698811  3.0054287  17.43401032  9.96903399  4.07700809
# ...

# %%
# Plotting relative errors vs time - FE
plt.scatter(t_1e2, rel_err_FE_1e2, color="black", label="$n=10^2$", s=1)
plt.scatter(t_1e3, rel_err_FE_1e3, color="blue", label="$n=10^3$", s=1)
plt.scatter(t_1e4, rel_err_FE_1e4, color="green", label="$n=10^4$", s=1)
plt.scatter(t_1e5, rel_err_FE_1e5, color="magenta", label="$n=10^5$", s=1)
plt.scatter(t_1e6, rel_err_FE_1e6, color="red", label="$n=10^6$", s=1)
#plt.scatter(t_1e7, rel_err_FE_1e7, color="yellow", label="$n=10^7$")

# add axis labels and legend
plt.xlabel("t [$\mu s$]")
plt.ylabel("rel_err [$\mu m$]")
plt.legend(loc='upper right')

# add grid
plt.grid(linestyle = '--', linewidth = 0.2)

# save plot as pdf
plt.savefig("plot_9h.pdf")

# %%
# Plotting absolute errors vs time - FE
#plt.scatter(t_1e2, rel_err_FE_1e2_abs, color="black", label="$n=10^2$", s=1)
plt.scatter(t_1e3, rel_err_FE_1e3_abs, color="blue", label="$n=10^3$", s=1)
plt.scatter(t_1e4, rel_err_FE_1e4_abs, color="green", label="$n=10^4$", s=1)
plt.scatter(t_1e5, rel_err_FE_1e5_abs, color="magenta", label="$n=10^5$", s=1)
plt.scatter(t_1e6, rel_err_FE_1e6_abs, color="red", label="$n=10^6$", s=1)
#plt.scatter(t_1e7, rel_err_FE_1e7, color="yellow", label="$n=10^7$")

# add axis labels and legend
plt.xlabel("t [$\mu s$]")
plt.ylabel("rel_abs [$\mu m$]")
plt.legend(loc='upper right')

# add grid
plt.grid(linestyle = '--', linewidth = 0.2)

# save plot as pdf
plt.savefig("plot_9h.pdf")

# %%
# Plotting relative errors vs time - RK
plt.scatter(t_1e2, rel_err_RK_1e2, color="black", label="$n=10^2$", s=1)
plt.scatter(t_1e3, rel_err_RK_1e3, color="blue", label="$n=10^3$", s=1)
plt.scatter(t_1e4, rel_err_RK_1e4, color="green", label="$n=10^4$", s=1)
plt.scatter(t_1e5, rel_err_RK_1e5, color="magenta", label="$n=10^5$", s=1)
plt.scatter(t_1e6, rel_err_RK_1e6, color="red", label="$n=10^6$", s=1)
#plt.scatter(t_1e7, rel_err_RK_1e7, color="yellow", label="$n=10^7$")

# add axis labels and legend
plt.xlabel("t [$\mu s$]")
plt.ylabel("rel_err [$\mu m$]")
plt.legend(loc='upper right')

# add grid
plt.grid(linestyle = '--', linewidth = 0.2)

# save plot as pdf
plt.savefig("plot_9i.pdf")

# %%
# Plotting absolute errors vs time - RK
plt.scatter(t_1e2, rel_err_RK_1e2_abs, color="black", label="$n=10^2$", s=1)
plt.scatter(t_1e3, rel_err_RK_1e3_abs, color="blue", label="$n=10^3$", s=1)
plt.scatter(t_1e4, rel_err_RK_1e4_abs, color="green", label="$n=10^4$", s=1)
plt.scatter(t_1e5, rel_err_RK_1e5_abs, color="magenta", label="$n=10^5$", s=1)
plt.scatter(t_1e6, rel_err_RK_1e6_abs, color="red", label="$n=10^6$", s=1)
#plt.scatter(t_1e7, rel_err_RK_1e7, color="yellow", label="$n=10^7$")

# add axis labels and legend
plt.xlabel("t [$\mu s$]")
plt.ylabel("rel_err [$\mu m$]")
plt.legend(loc='upper right')

# add grid
plt.grid(linestyle = '--', linewidth = 0.2)

# save plot as pdf
plt.savefig("plot_9i.pdf")

# %%
rel_err_RK_1e2.argsort()[-2:][::-1] #index of the first two max values
index = [61, 30]
rel_err_RK_1e2_new = np.delete(rel_err_RK_1e2, index)

# %%
rel_err_RK_1e3.argsort()[-2:][::-1] #index of the first two max values
rel_err_RK_1e4.argsort()[-2:][::-1] #index of the first two max values
rel_err_RK_1e5.argsort()[-2:][::-1] #index of the first two max values
rel_err_RK_1e6.argsort()[-2:][::-1] #index of the first two max values

# %%
t_tot = 100

h_1e2 = t_tot/1e2
h_1e3 = t_tot/1e3
h_1e4 = t_tot/1e4
h_1e5 = t_tot/1e5
h_1e6 = t_tot/1e6
#h_1e7 = t_tot/1e7

# Estimate error convergence rate FE
delta_max_FE_1e2 = np.max(abs_err_FE_1e2)
delta_max_FE_1e3 = np.max(abs_err_FE_1e3)
delta_max_FE_1e4 = np.max(abs_err_FE_1e4)
delta_max_FE_1e5 = np.max(abs_err_FE_1e5)
delta_max_FE_1e6 = np.max(abs_err_FE_1e6)
#delta_max_FE_1e7 = np.max(np.abs(r_1e7_an-r_1e7_FE_exp))

r_FE_1e3 = (math.log10(delta_max_FE_1e3/delta_max_FE_1e2))/(math.log10(h_1e3/h_1e2))
r_FE_1e4 = (math.log10(delta_max_FE_1e4/delta_max_FE_1e3))/(math.log10(h_1e4/h_1e3))
r_FE_1e5 = (math.log10(delta_max_FE_1e5/delta_max_FE_1e4))/(math.log10(h_1e5/h_1e4))
r_FE_1e6 = (math.log10(delta_max_FE_1e6/delta_max_FE_1e5))/(math.log10(h_1e6/h_1e5))
#r_FE_1e7 = (np.log10(delta_max_FE_1e7/delta_max_FE_1e6))/(np.log10(h_1e7/h_1e6))

print("error convergence rate FE n = 10^3: ", r_FE_1e3)
print("error convergence rate FE n = 10^4: ", r_FE_1e4)
print("error convergence rate FE n = 10^5: ", r_FE_1e5)
print("error convergence rate FE n = 10^6: ", r_FE_1e6)
#print("error convergence rate FE n = 10^7: ", r_FE_1e7)

r_FE = (r_FE_1e4+r_FE_1e5+r_FE_1e6+r_FE_1e3)/4

print("error convergence FE: ", r_FE)

print(delta_max_FE_1e3-delta_max_FE_1e2)
# Out:
# error convergence rate FE n = 10^3:  1.1443520604286677
# error convergence rate FE n = 10^4:  0.5036208088227605
# error convergence rate FE n = 10^5:  0.08062307667147207
# error convergence rate FE n = 10^6:  0.008936049277975712
# error convergence FE:  0.434382998800219
# -1434.160198681097

# %%
# Estimate error convergence rate RK
delta_max_RK_1e2 = np.max(abs_err_RK_1e2)
delta_max_RK_1e3 = np.max(abs_err_RK_1e3)
delta_max_RK_1e4 = np.max(abs_err_RK_1e4)
delta_max_RK_1e5 = np.max(abs_err_RK_1e5)
delta_max_RK_1e6 = np.max(abs_err_RK_1e6)
#delta_max_RK_1e7 = np.max(np.abs(r_1e7_an-r_1e7_RK_exp))

r_RK_1e3 = (math.log10(delta_max_RK_1e3/delta_max_RK_1e2))/(math.log10(h_1e3/h_1e2))
r_RK_1e4 = (math.log10(delta_max_RK_1e4/delta_max_RK_1e3))/(math.log10(h_1e4/h_1e3))
r_RK_1e5 = (math.log10(delta_max_RK_1e5/delta_max_RK_1e4))/(math.log10(h_1e5/h_1e4))
r_RK_1e6 = (math.log10(delta_max_RK_1e6/delta_max_RK_1e5))/(math.log10(h_1e6/h_1e5))
#r_RK_1e7 = (np.log10(delta_max_RK_1e7/delta_max_RK_1e6))/(np.log10(h_1e7/h_1e6))

print("error convergence rate RK n = 10^3: ", r_RK_1e3)
print("error convergence rate RK n = 10^4: ", r_RK_1e4)
print("error convergence rate RK n = 10^5: ", r_RK_1e5)
print("error convergence rate RK n = 10^6: ", r_RK_1e6)
#print("error convergence rate RK n = 10^7: ", r_RK_1e7)

r_RK = (r_RK_1e4+r_RK_1e5+r_RK_1e6+r_RK_1e3)/4

print("error convergence RK: ", r_RK)
# Out:
# error convergence rate RK n = 10^3:  0.04283562679140393
# error convergence rate RK n = 10^4:  0.00017856779981929622
# error convergence rate RK n = 10^5:  -3.0792400846447355e-06
# error convergence rate RK n = 10^6:  -0.0
# error convergence RK:  0.010752778837784645
# 31.144646817390626

# %%
# reading relative error - Runge-Kutta
r_1e1_RK_exp = np.loadtxt("rel_err_RK.100.txt", dtype='double')
r_1e2_RK_exp = np.loadtxt("rel_err_RK.200.txt", dtype='double')
r_1e3_RK_exp = np.loadtxt("rel_err_RK.400.txt", dtype='double')
r_1e4_RK_exp = np.loadtxt("rel_err_RK.800.txt", dtype='double')
r_1e5_RK_exp = np.loadtxt("rel_err_RK.1000.txt", dtype='double')
r_1e6_RK_exp = np.loadtxt("rel_err_RK.2000.txt", dtype='double')
r_1e7_RK_exp = np.loadtxt("rel_err_RK.4000.txt", dtype='double')
r_1e8_RK_exp = np.loadtxt("rel_err_RK.8000.txt", dtype='double')
r_1e9_RK_exp = np.loadtxt("rel_err_RK.10000.txt", dtype='double')
r_1e10_RK_exp = np.loadtxt("rel_err_RK.20000.txt", dtype='double')
r_1e11_RK_exp = np.loadtxt("rel_err_RK.40000.txt", dtype='double')
r_1e12_RK_exp = np.loadtxt("rel_err_RK.80000.txt", dtype='double')
r_1e13_RK_exp = np.loadtxt("rel_err_RK.100000.txt", dtype='double')
r_1e14_RK_exp = np.loadtxt("rel_err_RK.200000.txt", dtype='double')
r_1e15_RK_exp = np.loadtxt("rel_err_RK.400000.txt", dtype='double')
r_1e16_RK_exp = np.loadtxt("rel_err_RK.800000.txt", dtype='double')
#r_1e7_RK_exp = np.loadtxt("r1_nointer_RK_10000000.txt", dtype='double')

# reading relative error - Forward Euler
r_1e1_FE_exp = np.loadtxt("rel_err_FE.100.txt", dtype='double')
r_1e2_FE_exp = np.loadtxt("rel_err_FE.200.txt", dtype='double')
r_1e3_FE_exp = np.loadtxt("rel_err_FE.400.txt", dtype='double')
r_1e4_FE_exp = np.loadtxt("rel_err_FE.800.txt", dtype='double')
r_1e5_FE_exp = np.loadtxt("rel_err_FE.1000.txt", dtype='double')
r_1e6_FE_exp = np.loadtxt("rel_err_FE.2000.txt", dtype='double')
r_1e7_FE_exp = np.loadtxt("rel_err_FE.4000.txt", dtype='double')
r_1e8_FE_exp = np.loadtxt("rel_err_FE.8000.txt", dtype='double')
r_1e9_FE_exp = np.loadtxt("rel_err_FE.10000.txt", dtype='double')
r_1e10_FE_exp = np.loadtxt("rel_err_FE.20000.txt", dtype='double')
r_1e11_FE_exp = np.loadtxt("rel_err_FE.40000.txt", dtype='double')
r_1e12_FE_exp = np.loadtxt("rel_err_FE.80000.txt", dtype='double')
r_1e13_FE_exp = np.loadtxt("rel_err_FE.100000.txt", dtype='double')
r_1e14_FE_exp = np.loadtxt("rel_err_FE.200000.txt", dtype='double')
r_1e15_FE_exp = np.loadtxt("rel_err_FE.400000.txt", dtype='double')
r_1e16_FE_exp = np.loadtxt("rel_err_FE.800000.txt", dtype='double')

# %%
t1 = np.loadtxt("t_100.txt", dtype='double')
t2 = np.loadtxt("t_200.txt", dtype='double')
t3 = np.loadtxt("t_400.txt", dtype='double')
t4 = np.loadtxt("t_800.txt", dtype='double')
t5 = np.loadtxt("t_1000.txt", dtype='double')
t6 = np.loadtxt("t_2000.txt", dtype='double')
t7 = np.loadtxt("t_4000.txt", dtype='double')
t8 = np.loadtxt("t_8000.txt", dtype='double')
t9 = np.loadtxt("t_10000.txt", dtype='double')
t10 = np.loadtxt("t_20000.txt", dtype='double')
t11 = np.loadtxt("t_40000.txt", dtype='double')
t12 = np.loadtxt("t_80000.txt", dtype='double')
t13 = np.loadtxt("t_100000.txt", dtype='double')
t14 = np.loadtxt("t_200000.txt", dtype='double')
t15 = np.loadtxt("t_400000.txt", dtype='double')
t16 = np.loadtxt("t_800000.txt", dtype='double')

# %%
RK_rel=np.array((16))
t_tot=100.
h=[t_tot/100, t_tot/200, t_tot/400, t_tot/800, t_tot/1000, t_tot/2000, t_tot/4000, t_tot/8000, t_tot/10000, t_tot/20000, t_tot/40000, t_tot/80000, t_tot/100000, t_tot/200000, t_tot/400000, t_tot/800000 ]
plt.scatter(t1,np.log(np.ones(np.size(t1))*h[0]), c=r_1e1_RK_exp, cmap="viridis",norm=colors.LogNorm(vmin=0.0000000000001, vmax=max(r_1e1_RK_exp)) )
plt.scatter(t2,np.log(np.ones(np.size(t2))*h[1]), c=r_1e2_RK_exp, cmap="viridis",norm=colors.LogNorm(vmin=0.0000000000001, vmax=max(r_1e1_RK_exp)))
plt.scatter(t3,np.log(np.ones(np.size(t3))*h[2]), c=r_1e3_RK_exp, cmap="viridis",norm=colors.LogNorm(vmin=0.0000000000001, vmax=max(r_1e1_RK_exp)) )
plt.scatter(t4,np.log(np.ones(np.size(t4))*h[3]), c=r_1e4_RK_exp, cmap="viridis",norm=colors.LogNorm(vmin=0.0000000000001, vmax=max(r_1e1_RK_exp)) )
plt.scatter(t5,np.log(np.ones(np.size(t5))*h[4]), c=r_1e5_RK_exp, cmap="viridis",norm=colors.LogNorm(vmin=0.0000000000001, vmax=max(r_1e1_RK_exp)) )
plt.scatter(t6,np.log(np.ones(np.size(t6))*h[5]), c=r_1e6_RK_exp, cmap="viridis",norm=colors.LogNorm(vmin=0.0000000000001, vmax=max(r_1e1_RK_exp)) )
plt.scatter(t7,np.log(np.ones(np.size(t7))*h[6]), c=r_1e7_RK_exp, cmap="viridis",norm=colors.LogNorm(vmin=0.0000000000001, vmax=max(r_1e1_RK_exp)) )
plt.scatter(t8,np.log(np.ones(np.size(t8))*h[7]), c=r_1e8_RK_exp, cmap="viridis",norm=colors.LogNorm(vmin=0.0000000000001, vmax=max(r_1e1_RK_exp)) )
plt.scatter(t9,np.log(np.ones(np.size(t9))*h[8]), c=r_1e9_RK_exp, cmap="viridis",norm=colors.LogNorm(vmin=0.0000000000001, vmax=max(r_1e1_RK_exp)) )
plt.scatter(t10,np.log(np.ones(np.size(t10))*h[9]), c=r_1e10_RK_exp, cmap="viridis",norm=colors.LogNorm(vmin=0.0000000000001, vmax=max(r_1e1_RK_exp)))
plt.scatter(t11,np.log(np.ones(np.size(t11))*h[10]), c=r_1e11_RK_exp, cmap="viridis",norm=colors.LogNorm(vmin=0.0000000000001, vmax=max(r_1e1_RK_exp)) )
plt.scatter(t12,np.log(np.ones(np.size(t12))*h[11]), c=r_1e12_RK_exp, cmap="viridis",norm=colors.LogNorm(vmin=0.0000000000001, vmax=max(r_1e1_RK_exp)) )
plt.scatter(t13,np.log(np.ones(np.size(t13))*h[12]), c=r_1e13_RK_exp, cmap="viridis",norm=colors.LogNorm(vmin=0.0000000000001, vmax=max(r_1e1_RK_exp)) )
plt.scatter(t14,np.log(np.ones(np.size(t14))*h[13]), c=r_1e14_RK_exp, cmap="viridis",norm=colors.LogNorm(vmin=0.0000000000001, vmax=max(r_1e1_RK_exp)) )
plt.scatter(t15,np.log(np.ones(np.size(t15))*h[14]), c=r_1e15_RK_exp, cmap="viridis",norm=colors.LogNorm(vmin=0.0000000000001, vmax=max(r_1e1_RK_exp)))
plt.scatter(t16,np.log(np.ones(np.size(t16))*h[15]), c=r_1e16_RK_exp, cmap="viridis",norm=colors.LogNorm(vmin=0.0000000000001, vmax=max(r_1e1_RK_exp)))


plt.colorbar()


plt.xlabel("t [$\mu s$]")
plt.ylabel("h [$\mu s$]")
# Out:
# Text(0, 0.5, 'h [$\\mu s$]')

# %%
print(r_1e1_RK_exp)
# Out:
# [0.     0.1219 0.2029 0.3583 0.2217 0.2676 0.3667 0.2299 0.2971 0.3147
#  0.2211 0.3368 0.3029 0.2206 0.3409 0.2756 0.2334 0.3774 0.2477 0.2368
#  0.4082 0.2426 0.2488 0.3627 0.2308 0.279  0.3567 0.2198 0.2914 0.3376
#  0.2247 0.3167 0.2893 0.2243 0.3708 0.2746 0.2247 0.3684 0.259  0.2423
#  0.3779 0.235  0.2529 0.4023 0.231  0.2643 0.348  0.227  0.3029 0.3225
#  0.218  0.3236 0.3096 0.225  0.3391 0.2696 0.2317 0.396  0.2532 0.2332
#  0.3883 0.2458 0.2546 0.3649 0.227  0.2748 0.3751 0.2237 0.2851 0.3275
#  0.2264 0.3287 0.2928 0.2202 0.361  0.2837 0.2287 0.3587 0.2543 0.2431
#  0.4016 0.2378 0.2466 0.3919 0.2361 0.2703 0.3436 0.2231 0.3029 0.3398
#  0.2203 0.3114 0.3052 0.2288 0.3525 0.2693 0.2267 0.3961 0.2624 0.2358]
