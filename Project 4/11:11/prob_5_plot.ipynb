# %%
# multidimensional arrays
import numpy as np
import math

# inline plots
import matplotlib.pyplot as plt
# %matplotlib inline

# histogram
import seaborn as sbn

# nicer figures
import matplotlib as mpl
mpl.rcParams['axes.titlesize'] = 18
mpl.rcParams['axes.labelsize'] = 16
mpl.rcParams['xtick.labelsize'] = 14
mpl.rcParams['ytick.labelsize'] = 14
mpl.rcParams['legend.fontsize'] = 16
plt.rcParams["figure.figsize"] = (7,5)

# %%
#random initial state
#reading number of cycles, average energy and magnetization per particle L=2

# T=1
n_cycles = np.loadtxt("5a_rand_1_2.txt", usecols=0, dtype='double')
energy_1 = np.loadtxt("5a_rand_1_2.txt", usecols=1, dtype='double')
magn_1 = np.loadtxt("5a_rand_1_2.txt", usecols=2, dtype='double')

# T=2.4
energy_2 = np.loadtxt("5a_rand_2_2.txt", usecols=1, dtype='double')
magn_2 = np.loadtxt("5a_rand_2_2.txt", usecols=2, dtype='double')

# %%
#random initial state
#reading number of cycles, average energy and magnetization per particle L=20

# T=1
n_cycles_20 = np.loadtxt("5a_rand_1_20.txt", usecols=0, dtype='double')
energy_1_20 = np.loadtxt("5a_rand_1_20.txt", usecols=1, dtype='double')
magn_1_20 = np.loadtxt("5a_rand_1_20.txt", usecols=2, dtype='double')

# T=2.4
energy_2_20 = np.loadtxt("5a_rand_2_20.txt", usecols=1, dtype='double')
magn_2_20 = np.loadtxt("5a_rand_2_20.txt", usecols=2, dtype='double')

# %%
# Plotting energies - random initial state L=2
plt.plot(n_cycles, energy_1, color="blue",label="T=1 [J/$k_b$]")
plt.plot(n_cycles, energy_2, color="red",label="T=2.4 [J/$k_b$]")

# add axis labels and legend
plt.xlabel("Number of MC cycles")
plt.ylabel("<$\epsilon$> [J]")
plt.legend()

# add grid
plt.grid(linestyle = '--', linewidth = 0.2)
plt.title("Random initial state L=2")

# save plot as pdf
plt.savefig("Energy_rand_2.pdf")

# %%
# Plotting energies - T=2.4 L=20

plt.plot(n_cycles_20_ord, energy_2_20_ord, color="blue",label="Ordered")
plt.plot(n_cycles_20, energy_2_20, color="red",label="Random")

# add axis labels and legend
plt.xlabel("Number of MC cycles")
plt.ylabel("<$\epsilon$> [J]")
plt.legend()

# add grid
plt.grid(linestyle = '--', linewidth = 0.2)
plt.title("T=2.4 [J/$k_b$] L=20")

# save plot as pdf
plt.savefig("Energy_rand_20.pdf")

# %%
# Plotting magnetiziation - random initial state L=2
plt.plot(n_cycles, magn_1, color="blue",label="T=1 [J/$k_b$]")
plt.plot(n_cycles, magn_2, color="red",label="T=2.4 [J/$k_b$]")

# add axis labels and legend
plt.xlabel("Number of MC cycles")
plt.ylabel("<|m|>")
plt.legend()

# add grid
plt.grid(linestyle = '--', linewidth = 0.2)
plt.title("Random initial state L=2")

# save plot as pdf
plt.savefig("magn_rand_2.pdf")

# %%
# Plotting magnetiziation - random initial state L=20
plt.plot(n_cycles_20, magn_1_20, color="red",label="Random")
plt.plot(n_cycles_20_ord, magn_1_20_ord, color="blue",label="Ordered")
#plt.plot(n_cycles_20, magn_2_20, color="red",label="T=2.4 [J/$k_b$]")

# add axis labels and legend
plt.xlabel("Number of MC cycles")
plt.ylabel("<|m|>")
plt.legend()

# add grid
plt.grid(linestyle = '--', linewidth = 0.2)
plt.title("T=1 [J/$k_b$] L=20")
plt.xscale("log")
plt.ylim(0.99,1.01)

# save plot as pdf
plt.savefig("magn_rand_20.pdf")
# Out:
# /Users/Francescaferrero/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# /Users/Francescaferrero/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# /Users/Francescaferrero/opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#ordered initial state
#reading number of cycles, average energy and magnetization per particle L=2

# T=1
n_cycles_ord = np.loadtxt("5a_ord_1_2.txt", usecols=0, dtype='double')
energy_1_ord = np.loadtxt("5a_ord_1_2.txt", usecols=1, dtype='double')
magn_1_ord = np.loadtxt("5a_ord_1_2.txt", usecols=2, dtype='double')

# T=2.4
energy_2_ord = np.loadtxt("5a_ord_2_2.txt", usecols=1, dtype='double')
magn_2_ord = np.loadtxt("5a_ord_2_2.txt", usecols=2, dtype='double')

# %%
#ordered initial state
#reading number of cycles, average energy and magnetization per particle L=20

# T=1
n_cycles_20_ord = np.loadtxt("5a_ord_1_20.txt", usecols=0, dtype='double')
energy_1_20_ord = np.loadtxt("5a_ord_1_20.txt", usecols=1, dtype='double')
magn_1_20_ord = np.loadtxt("5a_ord_1_20.txt", usecols=2, dtype='double')

# T=2.4
energy_2_20_ord = np.loadtxt("5a_ord_2_20.txt", usecols=1, dtype='double')
magn_2_20_ord = np.loadtxt("5a_ord_2_20.txt", usecols=2, dtype='double')

# %%
# Plotting energies - ordered initial state L=2
plt.plot(n_cycles_ord, energy_1_ord, color="blue",label="T=1 [J/$k_b$]")
plt.plot(n_cycles_ord, energy_2_ord, color="red",label="T=2.4 [J/$k_b$]")

# add axis labels and legend
plt.xlabel("Number of MC cycles")
plt.ylabel("<$\epsilon$>")
plt.legend()

# add grid
plt.grid(linestyle = '--', linewidth = 0.2)
plt.title("Ordered initial state L=2")

# save plot as pdf
plt.savefig("Energy_ord_2.pdf")
# Out:
# /Users/Francescaferrero/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   from ipykernel import kernelapp as app
# /Users/Francescaferrero/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   from ipykernel import kernelapp as app
# /Users/Francescaferrero/opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Plotting energies - T=1 L=20
plt.plot(n_cycles_20_ord, energy_1_20_ord, color="blue",label="Ordered")
plt.plot(n_cycles_20, energy_1_20, color="red",label="Random")

#plt.plot(n_cycles_20_ord, energy_2_20_ord, color="red",label="T=2.4 [J/$k_b$]")

# add axis labels and legend
plt.xlabel("Number of MC cycles")
plt.ylabel("<$\epsilon$> [J]")
plt.legend()

# add grid
plt.grid(linestyle = '--', linewidth = 0.2)
plt.title("T=1 [J/$k_b$] L=20")
plt.ylim(-1.99,-2.01)

# save plot as pdf
plt.savefig("Energy_ord_20.pdf")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-2f0fdd7bf51e> in <module>
#       1 # Plotting energies - T=1 L=20
#       2 plt.plot(n_cycles_20_ord, energy_1_20_ord, color="blue",label="Ordered")
# ----> 3 plt.plot(n_cycles_20, energy_1_20, color="red",label="Random")
#       4
#       5 #plt.plot(n_cycles_20_ord, energy_2_20_ord, color="red",label="T=2.4 [J/$k_b$]")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
# ...

# %%
# Plotting magnetiziation - ordered initial state L=2
plt.plot(n_cycles_ord, magn_1_ord, color="blue",label="T=1 [J/$k_b$]")
plt.plot(n_cycles_ord, magn_2_ord, color="red",label="T=2.4 [J/$k_b$]")

# add axis labels and legend
plt.xlabel("Number of MC cycles")
plt.ylabel("<|m|>")
plt.legend()

# add grid
plt.grid(linestyle = '--', linewidth = 0.2)
plt.title("Ordered initial state L=2")

# save plot as pdf
plt.savefig("magn_ord_2.pdf")

# %%
# Plotting magnetiziation - ordered initial state L=20
#plt.plot(n_cycles_20_ord, magn_1_20_ord, color="blue",label="T=1 [J/$k_b$]")
plt.plot(n_cycles_20, magn_2_20, color="red",label="Random")
plt.plot(n_cycles_20_ord, magn_2_20_ord, color="blue",label="Ordered")

# add axis labels and legend
plt.xlabel("Number of MC cycles")
plt.ylabel("<|m|>")
plt.legend()

# add grid
plt.grid(linestyle = '--', linewidth = 0.2)
plt.title("T=2.4 [J/$k_b$] L=20")
#plt.ylim(0.4,0.5)

# save plot as pdf
plt.savefig("magn_ord_20.pdf")
# Out:
# /Users/Francescaferrero/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# /Users/Francescaferrero/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# /Users/Francescaferrero/opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#random initial state
#reading number of cycles, average energy and magnetization per particle L=20

# T=1
energy_1_20 = np.loadtxt("6_ord_1_20.txt", usecols=0, dtype='double')

# T=2.4
energy_2_20 = np.loadtxt("6_ord_2_20.txt", usecols=0, dtype='double')

# %%
# Plotting normalized histogram - random initial state
#sbn.histplot(energy_1_20, bins=32, stat="density", color="blue",label="T=1 [J/$k_b$]")
sbn.histplot(energy_2_20, bins=150, stat="density", color="red",label="T=2.4 [J/$k_b$]")

# add axis labels and legend
plt.xlabel("<$\epsilon$> [J]")
plt.ylabel("p$_{\epsilon}$($\epsilon$;T)")
plt.legend()

# add grid
plt.grid(linestyle = '--', linewidth = 0.2)
plt.title("Random initial state L=20")

# save plot as pdf
plt.savefig("histogram_rand.pdf")
plt.xlim(-1.28,-1.2)

# Computing and printing variances
print(np.var(energy_1_20))
print(np.var(energy_2_20))
# Out:
# 6.344743055839107e-09
# 2.4673059455118996e-05

# %%
sbn.histplot(energy_1_20, bins=150, stat="density", color="blue",label="T=1 [J/$k_b$]")
# add axis labels and legend
plt.xlabel("<$\epsilon$> [J]")
plt.ylabel("p$_{\epsilon}$($\epsilon$;T)")
plt.legend()

# add grid
plt.grid(linestyle = '--', linewidth = 0.2)
plt.title("Random initial state L=20")

# save plot as pdf
plt.savefig("histogram_rand.pdf")
#plt.xlim(-1.998,-1.996)

# Computing and printing variances
print(np.var(energy_1_20))
# Out:
# 6.344743055839107e-09

# %%
# Plotting normalized histogram - ordered initial state
sbn.histplot(energy_1_20_ord, bins=40, stat="density", color="blue",label="T=1 [J/$k_b$]")
#sbn.histplot(energy_2_20_ord, bins=32, stat="density", color="red",label="T=2.4 [J/$k_b$]")

# add axis labels and legend
plt.xlabel("<$\epsilon$> [J]")
plt.ylabel("p$_{\epsilon}$($\epsilon$;T)")
plt.legend()

# add grid
plt.grid(linestyle = '--', linewidth = 0.2)
plt.title("Ordered initial state L=20")
plt.xlim()

# save plot as pdf
plt.savefig("histogram_ord.pdf")

# Computing and printing variances
print(np.var(energy_1_20_ord))
print(np.var(energy_2_20_ord))
# Out:
# 4.8559639993603345e-09
# 1.3478643636075e-05
